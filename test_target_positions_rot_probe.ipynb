# %% [markdown]
# # Loading

# %%
import sys
import copy
import numpy
import modules.io as io
import modules.plot_func as pltt
import modules.helper_func_class as misc
import modules.process_mouse_trials_lib as plib
import matplotlib.pyplot as plt

# %% [markdown]
# # 11-Oct-2022 2-targets rot probe

# %% [markdown]
# ## mouse 1

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[0][0]
tr2 = track_grouped[0][1]
tr3 = track_grouped[0][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 2

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[1][0]
tr2 = track_grouped[1][1]
tr3 = track_grouped[1][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # 12-Aug-2022 2-targets rot probe

# %% [markdown]
# ## mouse 69

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[4][0]
tr2 = track_grouped[4][1]
tr3 = track_grouped[4][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 70

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[5][0]
tr2 = track_grouped[5][1]
tr3 = track_grouped[5][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # 20-Sept-2022 2-targets rot probe

# %% [markdown]
# ## mouse 73

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[8][0]
tr2 = track_grouped[8][1]
tr3 = track_grouped[8][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 74

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/reverse_probe/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[9][0]
tr2 = track_grouped[9][1]
tr3 = track_grouped[9][2]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # 04-Nov-2022 static entrance 90deg probe

# %% [markdown]
# ## probe (R90 and normal)

# %%
tracks = io.load_track_simple(['experiments/relative_target_90deg/mouse_1/mpos_04Nov2022_trial_Probe_startloc_SW_day_13.mat',
                               'experiments/relative_target_90deg/mouse_2/mpos_04Nov2022_trial_R90_startloc_SW_day_13.mat',
                               'experiments/relative_target_90deg/mouse_3/mpos_04Nov2022_trial_Probe_startloc_NE_day_13.mat',
                               'experiments/relative_target_90deg/mouse_4/mpos_04Nov2022_trial_R90_startloc_NE_day_13.mat'])
tracks
# Out:
# [trackfile(file_name='Raw data-Hidden Food Maze-04Nov2022-Trial   102.xlsx', day='13', exper_date='04Nov2022', is_reverse=0, mouse_gender='M', mouse_number='1', start_location='SW', start_quadrant=2, trial='Probe', arena_picture='BKGDimage-20221104_cropped.png', arena_picture_extent=[-105.53609805924413, 92.53703779366703, -72.46542805100178, 76.50943533697632]),
#  trackfile(file_name='Raw data-Hidden Food Maze-04Nov2022-Trial   103.xlsx', day='13', exper_date='04Nov2022', is_reverse=1, mouse_gender='M', mouse_number='2', start_location='SW', start_quadrant=2, trial='R90', arena_picture='BKGDimage-20221104_cropped.png', arena_picture_extent=[-105.53609805924413, 92.53703779366703, -72.46542805100178, 76.50943533697632]),
# ...

# %%
tracks = io.load_track_simple(['experiments/relative_target_90deg/mouse_1/mpos_04Nov2022_trial_Probe_startloc_SW_day_13.mat',
                               'experiments/relative_target_90deg/mouse_2/mpos_04Nov2022_trial_R90_startloc_SW_day_13.mat',
                               'experiments/relative_target_90deg/mouse_3/mpos_04Nov2022_trial_Probe_startloc_NE_day_13.mat',
                               'experiments/relative_target_90deg/mouse_4/mpos_04Nov2022_trial_R90_startloc_NE_day_13.mat'])

tr1 = tracks[1]
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr1 = tracks[3]
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr1 = tracks[0]
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr1 = tracks[2]
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

# %% [markdown]
# ## mouse 1

# %%
track_grouped[0]
# Out:
# [trackfile(file_name='Raw data-Hidden Food Maze-04Nov2022-Trial    98.xlsx', day='12', exper_date='04Nov2022', is_reverse=0, mouse_gender='M', mouse_number='1', start_location='SW', start_quadrant=2, trial='21', arena_picture='BKGDimage-20221104_cropped.png', arena_picture_extent=[-105.53609805924413, 92.53703779366703, -72.46542805100178, 76.50943533697632]),
#  trackfile(file_name='Raw data-Hidden Food Maze-04Nov2022-Trial   102.xlsx', day='13', exper_date='04Nov2022', is_reverse=0, mouse_gender='M', mouse_number='1', start_location='SW', start_quadrant=2, trial='Probe', arena_picture='BKGDimage-20221104_cropped.png', arena_picture_extent=[-105.53609805924413, 92.53703779366703, -72.46542805100178, 76.50943533697632])]

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/90deg/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[0][0]
tr3 = track_grouped[0][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
#tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
#tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
#tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
#tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 2

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/90deg/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[1][0]
tr3 = track_grouped[1][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
#tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
#tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
#tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
#tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 3

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/90deg/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[2][0]
tr3 = track_grouped[2][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
#tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
#tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
#tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
#tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ## mouse 4

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

track            = io.load_track_simple('debug_preprocess/90deg/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')

tr1 = track_grouped[3][0]
tr3 = track_grouped[3][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
#tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
#tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
#tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
#tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # 23-May-2019 - Preliminary experiments (fixed target, but different target for each entrance)

# %% [markdown]
# ## mouse 6

# %%
del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

# track=io.load_track_simple(['experiments/preliminary/mouse_5/mpos_23May2019_trial_13_startloc_SW_day_12.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_13_startloc_SE_day_12.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_13_startloc_NE_day_12.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_13_startloc_NW_day_12.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_Flip_1_startloc_NE_day_15.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_Flip_1_startloc_NW_day_15.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_Flip_1_startloc_SW_day_15.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_Flip_1_startloc_SE_day_15.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_R90_6_startloc_NW_day_23.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_R90_6_startloc_SW_day_23.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_R90_6_startloc_SE_day_23.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_R90_6_startloc_NE_day_23.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_R270_6_startloc_SE_day_20.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_R270_6_startloc_NE_day_20.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_R270_6_startloc_NW_day_20.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_R270_6_startloc_SW_day_20.mat'])
track            = io.load_track_simple('debug_preprocess/preliminary/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')


tr1 = track_grouped[1][0]
tr3 = track_grouped[1][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # 06-Sept-2019 relative target (static entrance default experiment)

# %% [markdown]
# ## mouse 10

# %%
#track            = io.load_track_simple([ 'experiments/relative_target/mouse_9/mpos_06Sept2019_trial_14_startloc_SW_day_12.mat','experiments/relative_target/mouse_10/mpos_06Sept2019_trial_14_startloc_SE_day_12.mat','experiments/relative_target/mouse_11/mpos_06Sept2019_trial_14_startloc_NE_day_12.mat','experiments/relative_target/mouse_12/mpos_06Sept2019_trial_14_startloc_NW_day_12.mat', 'experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R180_6_startloc_NE_day_17.mat','experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R180_6_startloc_NW_day_17.mat','experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R180_6_startloc_SW_day_17.mat','experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R180_6_startloc_SE_day_17.mat', 'experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R90_6_startloc_SE_day_23.mat','experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R90_6_startloc_NE_day_23.mat','experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R90_6_startloc_NW_day_23.mat','experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R90_6_startloc_SW_day_23.mat', 'experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R270_6_startloc_NW_day_20.mat','experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R270_6_startloc_SW_day_20.mat','experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R270_6_startloc_SE_day_20.mat','experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R270_6_startloc_NE_day_20.mat' ])
#[tr.file_name for tr in track]



del sys.modules['modules.process_mouse_trials_lib']
del plib
import modules.process_mouse_trials_lib as plib

# track=io.load_track_simple(['experiments/preliminary/mouse_5/mpos_23May2019_trial_13_startloc_SW_day_12.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_13_startloc_SE_day_12.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_13_startloc_NE_day_12.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_13_startloc_NW_day_12.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_Flip_1_startloc_NE_day_15.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_Flip_1_startloc_NW_day_15.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_Flip_1_startloc_SW_day_15.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_Flip_1_startloc_SE_day_15.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_R90_6_startloc_NW_day_23.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_R90_6_startloc_SW_day_23.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_R90_6_startloc_SE_day_23.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_R90_6_startloc_NE_day_23.mat','experiments/preliminary/mouse_5/mpos_23May2019_trial_R270_6_startloc_SE_day_20.mat','experiments/preliminary/mouse_6/mpos_23May2019_trial_R270_6_startloc_NE_day_20.mat','experiments/preliminary/mouse_7/mpos_23May2019_trial_R270_6_startloc_NW_day_20.mat','experiments/preliminary/mouse_8/mpos_23May2019_trial_R270_6_startloc_SW_day_20.mat'])
track            = io.load_track_simple('debug_preprocess/rel_tgt/mouse_*')
track_grouped, _ = io.group_track_list(track,group_by='mouse')
track_R180       = io.load_trial_file(r'./experiments/relative_target/mouse_*',file_name_expr='mpos_*_R180_1*',load_only_training_sessions_relative_target=False,skip_15_relative_target=True,use_extra_trials_relative_target=True,sort_by_trial=True,fix_nan=True,remove_after_food=False,group_by='none')


tr1 = track_grouped[1][0]
tr2 = track_R180[0]
tr3 = track_grouped[1][1]

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr1.exper_date} -- mouse = {tr1.mouse_number} -- trial = {tr1.trial}')
pltt.plot_arena_sketch(tr1,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr1.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr1.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr1.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr1.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

print('R180')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2.mouse_number} -- trial = {tr2.trial}')
pltt.plot_arena_sketch(tr2,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

print('R180 CORRECTED')

tr2_corrected                      = copy.deepcopy(tr2)
tr2_corrected.r_target             = plib.get_arena_target(tr2_corrected)
tr2_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr2_corrected)
tr2_corrected.r_target_alt         = plib.get_arena_alt_target(tr2_corrected)
tr2_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr2_corrected)

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr2.exper_date} -- mouse = {tr2_corrected.mouse_number} -- trial = {tr2_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr2_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr2_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr2_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr2_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr2_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

print('R90')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3.mouse_number} -- trial = {tr3.trial}')
pltt.plot_arena_sketch(tr3,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

tr3_corrected                      = copy.deepcopy(tr3)
tr3_corrected.r_target             = plib.get_arena_target(tr3_corrected)
tr3_corrected.r_target_reverse     = plib.get_arena_reverse_target(tr3_corrected)
tr3_corrected.r_target_alt         = plib.get_arena_alt_target(tr3_corrected)
tr3_corrected.r_target_alt_reverse = plib.get_arena_alt_reverse_target(tr3_corrected)

print('R90 CORRECTED')

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,6))
ax.set_title(f'exper_date = {tr3.exper_date} -- mouse = {tr3_corrected.mouse_number} -- trial = {tr3_corrected.trial} CORRECTED')
pltt.plot_arena_sketch(tr3_corrected,showAllEntrances=True,showHoles=True,showArenaCircle=True,showStart=True,ax=ax)
pltt.plot_point(tr3_corrected.r_target            ,'target'            , fmt='o', color='r', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='r')
pltt.plot_point(tr3_corrected.r_target_alt        ,'target_alt'        , fmt='s', color='b', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='b')
pltt.plot_point(tr3_corrected.r_target_reverse    ,'target_reverse'    , fmt='^', color='g', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='g')
pltt.plot_point(tr3_corrected.r_target_alt_reverse,'target_alt_reverse', fmt='v', color='m', markersize=10, pointArgs=dict(markeredgewidth=2), labelcolor='m')
ax.set_aspect('equal')

plt.show()
# Out:
# R180
# R180 CORRECTED
# R90
# R90 CORRECTED
