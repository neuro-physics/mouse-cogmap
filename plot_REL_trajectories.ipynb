# %%
print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### Normal training trials ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/preliminary/mouse_5/mpos_23May2019_trial_13_startloc_SW_day_12.mat -color time -stopfood
# %run plot_mouse_trial.py experiments/preliminary/mouse_6/mpos_23May2019_trial_13_startloc_SE_day_12.mat -color time -stopfood
# %run plot_mouse_trial.py experiments/preliminary/mouse_7/mpos_23May2019_trial_13_startloc_NE_day_12.mat -color time -stopfood
# %run plot_mouse_trial.py experiments/preliminary/mouse_8/mpos_23May2019_trial_13_startloc_NW_day_12.mat -color time -stopfood

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 180 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/preliminary/mouse_5/mpos_23May2019_trial_Flip_1_startloc_NE_day_15.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_6/mpos_23May2019_trial_Flip_1_startloc_NW_day_15.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_7/mpos_23May2019_trial_Flip_1_startloc_SW_day_15.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_8/mpos_23May2019_trial_Flip_1_startloc_SE_day_15.mat -showrel -color time -stoprel

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 90 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/preliminary/mouse_5/mpos_23May2019_trial_R90_6_startloc_NW_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_6/mpos_23May2019_trial_R90_6_startloc_SW_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_7/mpos_23May2019_trial_R90_6_startloc_SE_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_8/mpos_23May2019_trial_R90_6_startloc_NE_day_23.mat -showrel -color time -stoprel

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 270 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/preliminary/mouse_5/mpos_23May2019_trial_R270_6_startloc_SE_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_6/mpos_23May2019_trial_R270_6_startloc_NE_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_7/mpos_23May2019_trial_R270_6_startloc_NW_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/preliminary/mouse_8/mpos_23May2019_trial_R270_6_startloc_SW_day_20.mat -showrel -color time -stoprel
# Out:
# #########################
# #########################
# #########################
# #########################
# ######################### Normal training trials
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 180 deg rotated training
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 90 deg rotated training
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 270 deg rotated training
# #########################
# #########################

# %%
print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### Normal training trials ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py  experiments/relative_target/mouse_9/mpos_06Sept2019_trial_14_startloc_SW_day_12.mat -showrel -color time -stopfood
# %run plot_mouse_trial.py experiments/relative_target/mouse_10/mpos_06Sept2019_trial_14_startloc_SE_day_12.mat -showrel -color time -stopfood
# %run plot_mouse_trial.py experiments/relative_target/mouse_11/mpos_06Sept2019_trial_14_startloc_NE_day_12.mat -showrel -color time -stopfood
# %run plot_mouse_trial.py experiments/relative_target/mouse_12/mpos_06Sept2019_trial_14_startloc_NW_day_12.mat -showrel -color time -stopfood

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 180 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py  experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R180_6_startloc_NE_day_17.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R180_6_startloc_NW_day_17.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R180_6_startloc_SW_day_17.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R180_6_startloc_SE_day_17.mat -showrel -color time -stoprel

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 90 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py  experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R90_6_startloc_SE_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R90_6_startloc_NE_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R90_6_startloc_NW_day_23.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R90_6_startloc_SW_day_23.mat -showrel -color time -stoprel

print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 270 deg rotated training ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py  experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R270_6_startloc_NW_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R270_6_startloc_SW_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R270_6_startloc_SE_day_20.mat -showrel -color time -stoprel
# %run plot_mouse_trial.py experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R270_6_startloc_NE_day_20.mat -showrel -color time -stoprel
# Out:
# #########################
# #########################
# #########################
# #########################
# ######################### Normal training trials
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 180 deg rotated training
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 90 deg rotated training
# #########################
# #########################
# #########################
# #########################
# #########################
# #########################
# ######################### 270 deg rotated training
# #########################
# #########################

# %%
# %run plot_mouse_trial.py  experiments/relative_target/mouse_9/mpos_06Sept2019_trial_R180_1_startloc_NE_day_15.mat -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_10/mpos_06Sept2019_trial_R180_1_startloc_NW_day_15.mat -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_11/mpos_06Sept2019_trial_R180_1_startloc_SW_day_15.mat -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_12/mpos_06Sept2019_trial_R180_1_startloc_SE_day_15.mat -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_13/mpos_07Oct2019_trial_R180_1_startloc_NE_day_15.mat  -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_14/mpos_07Oct2019_trial_R180_1_startloc_NW_day_15.mat  -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_15/mpos_07Oct2019_trial_R180_1_startloc_SW_day_15.mat  -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target/mouse_16/mpos_07Oct2019_trial_R180_1_startloc_SE_day_15.mat  -showrel -color time -stoprel -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9

# %% [markdown]
# # 04Nov2022 - static target - 90R probe

# %%
print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### last training trial')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_1/mpos_04Nov2022_trial_21_startloc_SW_day_12.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_2/mpos_04Nov2022_trial_21_startloc_SE_day_12.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_3/mpos_04Nov2022_trial_21_startloc_NE_day_12.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_4/mpos_04Nov2022_trial_21_startloc_NW_day_12.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# Out:
# #########################
# #########################
# #########################
# #########################
# ######################### last training trial
# #########################
# #########################

# %%
print('#########################')
print('#########################')
print('#########################')
print('#########################')
print('######################### 90 deg rotated Probe ')
print('#########################')
print('#########################')

# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_1/mpos_04Nov2022_trial_Probe_startloc_SW_day_13.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_2/mpos_04Nov2022_trial_R90_startloc_SW_day_13.mat    -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_3/mpos_04Nov2022_trial_Probe_startloc_NE_day_13.mat  -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# %run plot_mouse_trial.py experiments/relative_target_90deg/mouse_4/mpos_04Nov2022_trial_R90_startloc_NE_day_13.mat    -showrel -color time -stopfood -showchecks -L 11 -lattalpha 0.5 -lattgridalpha 0.9
# Out:
# #########################
# #########################
# #########################
# #########################
# ######################### 90 deg rotated Probe
# #########################
# #########################
